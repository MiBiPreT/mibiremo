# %%
print("Hello Matteo!")
# Out:
# Hello Matteo!

# %%
print("You can add/remove notebooks in the mkdocs.yml (look in the nav: section)")
# Out:
# You can add/remove notebooks in the mkdocs.yml (look in the nav: section)
